# %% [markdown]
# # Getaround

# %% [markdown]
# ## EDA

# %%
import pandas as pd

import plotly.graph_objects as go
import plotly.express as px

import os

# %%
data_path = os.getcwd() + "/data/"

df_delay = pd.read_excel(data_path+"get_around_delay_analysis.xlsx", sheet_name="rentals_data")

# %%
# Useful function
def remove_outliers_from_column(df, column, std_ratio=3) :

    mask = (df[column] > df[column].mean() - std_ratio * df[column].std()) & (df[column] < df[column].mean() + std_ratio * df[column].std())

    return df.loc[mask]

# %%
display(df_delay.head())
display(df_delay.describe(include="all"))
display(df_delay.isna().sum())
# Out:
#    rental_id  car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0     505000  363965       mobile  canceled                           NaN
# 1     507750  269550       mobile     ended                         -81.0
# 2     508131  359049      connect     ended                          70.0
# 3     508865  299063      connect  canceled                           NaN
# 4     511440  313932       mobile     ended                           NaN
#
#    previous_ended_rental_id  time_delta_with_previous_rental_in_minutes
# 0                       NaN                                         NaN
# 1                       NaN                                         NaN
# 2                       NaN                                         NaN
# 3                       NaN                                         NaN
# 4                       NaN                                         NaN
#             rental_id         car_id checkin_type  state  \
# ...

# %%
fig_1 = px.violin(
    data_frame=df_delay[df_delay['delay_at_checkout_in_minutes']>0],
    x="delay_at_checkout_in_minutes",

    color_discrete_sequence=[px.colors.qualitative.G10[0]]
)

fig_1.update_layout(
    # title="Delay at checkout distribution", => Title on Streamlit
    yaxis_title="Total",
    xaxis_title="Delay at checkout "
)

fig_1.show()

# %%
def delay_interval(delay) :

    if delay <= 0:
        interval = "0"
    elif delay < 20:
        interval = "0' - 20'"
    elif delay < 40:
        interval = "20' - 40'"
    elif delay < 60:
        interval = "40' - 60'"
    elif delay < 120 :
        interval = "60' - 120'"
    elif delay >= 120 :
        interval = "120' +"        
    else :
        interval = "NA"

    return interval

df_delay["delay_interval"] = df_delay["delay_at_checkout_in_minutes"].transform(delay_interval)

df_delay["has_previous_rental"] = [True if x > 0 else False for x in df_delay["previous_ended_rental_id"]]

df_delay.head(20)
# Out:
#     rental_id  car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0      505000  363965       mobile  canceled                           NaN
# 1      507750  269550       mobile     ended                         -81.0
# 2      508131  359049      connect     ended                          70.0
# 3      508865  299063      connect  canceled                           NaN
# 4      511440  313932       mobile     ended                           NaN
# 5      511626  398802       mobile     ended                        -203.0
# 6      511639  370585      connect     ended                         -15.0
# 7      512303  371242       mobile     ended                         -44.0
# 8      512475  322502       mobile  canceled                           NaN
# 9      513434  256528      connect     ended                          23.0
# 10     513743  330658       mobile  canceled                           NaN
# ...
